# %%
import requests
# !pip install pydub
from pydub import AudioSegment
from pydub.utils import make_chunks

API_URL = "https://api-inference.huggingface.co/models/openai/whisper-large-v3"
headers = {"Authorization": "Bearer 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"}

def hf_whisper_query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

output = hf_whisper_query(r"IP.mp3")

# %%
# output
# !pip install transformers
# !pip install datasets
import requests

API_URL = "https://api-inference.huggingface.co/models/distil-whisper/distil-large-v2"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

output = query("IP.mp3")

# %%
output
# Out:
# {'text': "! Cocoa melon! Ah!! Humpty, Dumpty, have a grape hall. All the king's horses and all the king's men. Couldn't put Humpty together again.! Humpty sat on a wall. Humpty, down to have a great fall. Obligate kins were seated in obliquished men. Couldn't play Manti together again.! Huntie, dente sat on a wall. Hunt, dente, had a creep all. All the things were seated, only things men. Couldn't put hanty together again.! Humpty, Dumpty sat on a wall. Humpty, Dumpty, have a great hall. All the things horses and all the things men. Can and put Humpty together again.! Yeah!"}

# %%
from deepgram import DeepgramClient, PrerecordedOptions

# The API key we created in step 3
DEEPGRAM_API_KEY = '970a72018ea74c7a4b82ee1213720cee95954721'

# Replace with your file path
PATH_TO_FILE = 'input_audio.mp3'

def main():
    deepgram = DeepgramClient(DEEPGRAM_API_KEY)

    with open(PATH_TO_FILE, 'rb') as buffer_data:
        payload = { 'buffer': buffer_data }

        options = PrerecordedOptions(
            smart_format=True, model="nova-2", language="en-US", paragraphs = True
        )

        print('Requesting transcript...')
        print('Your file may take up to a couple minutes to process.')
        print('While you wait, did you know that Deepgram accepts over 40 audio file formats? Even MP4s.')
        print('To learn more about customizing your transcripts check out developers.deepgram.com')

        response = deepgram.listen.prerecorded.v('1').transcribe_file(payload, options)
        print(response.to_json(indent=4))
        return response.to_json(indent=4)

if __name__ == '__main__':
    op = main()
# Out:
# Requesting transcript...
# Your file may take up to a couple minutes to process.
# While you wait, did you know that Deepgram accepts over 40 audio file formats? Even MP4s.
# To learn more about customizing your transcripts check out developers.deepgram.com
# {
#     "metadata": {
#         "transaction_key": "deprecated",
#         "request_id": "f50dbf46-efc6-465c-9382-dc03cd1c7b68",
#         "sha256": "26cc2bf810e245adb40c3d3551210ead2ee58b429a94ea3c36b4151fafea33ba",
#         "created": "2024-04-26T20:23:13.978Z",
#         "duration": 1703.6278,
#         "channels": 1,
#         "models": [
#             "30089e05-99d1-4376-b32e-c263170674af"
#         ],
#         "model_info": {
#             "30089e05-99d1-4376-b32e-c263170674af": {
#                 "name": "2-general-nova",
#                 "version": "2024-01-09.29447",
#                 "arch": "nova-2"
#             }
#         }
#     },
#     "results": {
#         "channels": [
#             {
# ...

# %%
# import json
opdata = json.loads(op)
description = opdata['results']['channels']
description[0]['alternatives'][0]['paragraphs']['paragraphs']

for i in range(0,len(description[0]['alternatives'][0]['paragraphs']['paragraphs'])):
    # print(i)
    print(description[0]['alternatives'][0]['paragraphs']['paragraphs'][i])
# Out:
# {'sentences': [{'text': 'From that API response from raw text to a dictionary in a controllable way, that changes everything.', 'start': 0.24, 'end': 7.585}, {'text': 'Alright.', 'start': 8.145, 'end': 8.645}, {'text': 'Open AI function calling.', 'start': 8.705, 'end': 10.565001}, {'text': "This is a very exciting new feature but it's a bit of a tricky one.", 'start': 10.705, 'end': 13.825}, {'text': 'You have to see some examples, play around with it in order to like fully grasp the idea and the possibilities here.', 'start': 13.825, 'end': 19.55}], 'start': 0.24, 'end': 19.55, 'num_words': 59}
# ...
